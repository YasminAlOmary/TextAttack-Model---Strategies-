# %%
# !pip install textattack
# Out:
# Collecting textattack
#   Downloading textattack-0.3.10-py3-none-any.whl.metadata (38 kB)
# Collecting bert-score>=0.3.5 (from textattack)
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.11/dist-packages (from textattack) (0.8.1)
# Collecting flair (from textattack)
#   Downloading flair-0.15.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from textattack) (3.17.0)
# Collecting language-tool-python (from textattack)
#   Downloading language_tool_python-2.9.0-py3-none-any.whl.metadata (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.9 MB/s eta 0:00:00
# Collecting lemminflect (from textattack)
#   Downloading lemminflect-0.2.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting lru-dict (from textattack)
#   Downloading lru_dict-1.3.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting datasets>=2.4.0 (from textattack)
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from textattack) (3.9.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from textattack) (1.26.4)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from textattack) (2.2.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from textattack) (1.13.1)
# Requirement already satisfied: torch!=1.8,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from textattack) (2.5.1+cu124)
# Requirement already satisfied: transformers>=4.30.0 in /usr/local/lib/python3.11/dist-packages (from textattack) (4.48.3)
# Collecting terminaltables (from textattack)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from textattack) (4.67.1)
# Collecting word2number (from textattack)
#   Downloading word2number-1.1.zip (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting num2words (from textattack)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from textattack) (10.6.0)
# Collecting pinyin>=0.4.0 (from textattack)
#   Downloading pinyin-0.4.0.tar.gz (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 42.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from textattack) (0.42.1)
# Collecting OpenHowNet (from textattack)
#   Downloading OpenHowNet-2.0-py3-none-any.whl.metadata (821 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from bert-score>=0.3.5->textattack) (2.32.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert-score>=0.3.5->textattack) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from bert-score>=0.3.5->textattack) (24.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.4.0->textattack)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting xxhash (from datasets>=2.4.0->textattack)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.4.0->textattack)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.4.0->textattack) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (3.11.12)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->textattack) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->textattack) (2025.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch!=1.8,>=1.7.0->textattack) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1.5)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch!=1.8,>=1.7.0->textattack) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch!=1.8,>=1.7.0->textattack) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch!=1.8,>=1.7.0->textattack)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch!=1.8,>=1.7.0->textattack) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch!=1.8,>=1.7.0->textattack) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch!=1.8,>=1.7.0->textattack) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.30.0->textattack) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.30.0->textattack) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.30.0->textattack) (0.5.2)
# Collecting boto3>=1.20.27 (from flair->textattack)
#   Downloading boto3-1.36.26-py3-none-any.whl.metadata (6.7 kB)
# Collecting conllu<5.0.0,>=4.0 (from flair->textattack)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (1.2.18)
# Collecting ftfy>=6.1.0 (from flair->textattack)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (5.2.0)
# Collecting langdetect>=1.0.9 (from flair->textattack)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 45.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (5.3.1)
# Collecting mpld3>=0.3 (from flair->textattack)
#   Downloading mpld3-0.5.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting pptree>=3.1 (from flair->textattack)
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pytorch-revgrad>=0.2.0 (from flair->textattack)
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (1.6.1)
# Collecting segtok>=1.5.11 (from flair->textattack)
#   Downloading segtok-1.5.11-py3-none-any.whl.metadata (9.0 kB)
# Collecting sqlitedict>=2.0.0 (from flair->textattack)
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (0.9.0)
# Collecting transformer-smaller-training-vocab>=0.2.3 (from flair->textattack)
#   Downloading transformer_smaller_training_vocab-0.4.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting wikipedia-api>=0.5.7 (from flair->textattack)
#   Downloading wikipedia_api-0.8.1.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bioc<3.0.0,>=2.0.0 (from flair->textattack)
#   Downloading bioc-2.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from language-tool-python->textattack) (5.9.5)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from language-tool-python->textattack) (0.10.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->textattack) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->textattack) (1.4.2)
# Collecting docopt>=0.6.2 (from num2words->textattack)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting anytree (from OpenHowNet->textattack)
#   Downloading anytree-2.12.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from OpenHowNet->textattack) (75.1.0)
# Collecting jsonlines>=1.2.0 (from bioc<3.0.0,>=2.0.0->flair->textattack)
#   Downloading jsonlines-4.0.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting intervaltree (from bioc<3.0.0,>=2.0.0->flair->textattack)
#   Downloading intervaltree-3.1.0.tar.gz (32 kB)
#   Preparing metadata (setup.py) ... done
# Collecting botocore<1.37.0,>=1.36.26 (from boto3>=1.20.27->flair->textattack)
#   Downloading botocore-1.36.26-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.20.27->flair->textattack)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3>=1.20.27->flair->textattack)
#   Downloading s3transfer-0.11.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.13->flair->textattack) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.18.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy>=6.1.0->flair->textattack) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=4.4.0->flair->textattack) (4.13.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect>=1.0.9->flair->textattack) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score>=0.3.5->textattack) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score>=0.3.5->textattack) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score>=0.3.5->textattack) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->bert-score>=0.3.5->textattack) (2025.1.31)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->flair->textattack) (3.5.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair->textattack) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair->textattack) (4.25.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch!=1.8,>=1.7.0->textattack) (3.0.2)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece,torch]<5.0,>=4.1->transformer-smaller-training-vocab>=0.2.3->flair->textattack) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=4.4.0->flair->textattack) (2.6)
# Collecting sortedcontainers<3.0,>=2.0 (from intervaltree->bioc<3.0.0,>=2.0.0->flair->textattack)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=4.4.0->flair->textattack) (1.7.1)
# Downloading textattack-0.3.10-py3-none-any.whl (445 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.7/445.7 kB 35.1 MB/s eta 0:00:00
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.8 MB/s eta 0:00:00
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 31.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 49.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.1 MB/s eta 0:00:00
# Downloading flair-0.15.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.4 MB/s eta 0:00:00
# Downloading language_tool_python-2.9.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.1 MB/s eta 0:00:00
# Downloading lemminflect-0.2.3-py3-none-any.whl (769 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.7/769.7 kB 47.8 MB/s eta 0:00:00
# Downloading lru_dict-1.3.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.5/163.5 kB 13.5 MB/s eta 0:00:00
# Downloading OpenHowNet-2.0-py3-none-any.whl (18 kB)
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Downloading bioc-2.1-py3-none-any.whl (33 kB)
# Downloading boto3-1.36.26-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 12.0 MB/s eta 0:00:00
# Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.2 MB/s eta 0:00:00
# Downloading mpld3-0.5.10-py3-none-any.whl (202 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.6/202.6 kB 15.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 8.8 MB/s eta 0:00:00
# Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Downloading transformer_smaller_training_vocab-0.4.0-py3-none-any.whl (14 kB)
# Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.1 MB/s eta 0:00:00
# Downloading botocore-1.36.26-py3-none-any.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 69.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading jsonlines-4.0.0-py3-none-any.whl (8.7 kB)
# Downloading s3transfer-0.11.2-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 kB 5.5 MB/s eta 0:00:00
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Building wheels for collected packages: pinyin, word2number, docopt, langdetect, pptree, sqlitedict, wikipedia-api, intervaltree
#   Building wheel for pinyin (setup.py) ... done
#   Created wheel for pinyin: filename=pinyin-0.4.0-py3-none-any.whl size=3630477 sha256=fda1ae0cdacd6927916ab576ca3473c3dd07697e6c42efc057ae104049e8d004
#   Stored in directory: /root/.cache/pip/wheels/1c/f5/31/ac8c91eccb570a59fe5f1471ad9f11bece8f4fd4be1ab1be25
#   Building wheel for word2number (setup.py) ... done
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=805492c7526c5ba29fa5bd0e01e32baa5d497749f4e28061f28606e4bd60a6ec
#   Stored in directory: /root/.cache/pip/wheels/cd/ef/ae/073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=9242b29a9416ba72ffbecaa6a0c2f2d3834ccaba5b6068a1985797b6e88add92
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=f9f18a6454bb4694a6063f7ed01e7dbc9c83c96627ce8511da95c64477a1340d
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4608 sha256=4649c655599cd92e3ee1b6b8a75f68b3a6b23ab66e2f566a2d63f2ab9598e1ba
#   Stored in directory: /root/.cache/pip/wheels/68/8a/eb/d683aa6d09dc68ebfde2f37566ddc8807837c4415b4fd2b04c
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16864 sha256=6673b7f33837cacfd821ee0429f3e4eafe3653baec9114f846618d19f84d897b
#   Stored in directory: /root/.cache/pip/wheels/73/63/89/7210274f9b7fb033b8f22671f64c0e0b55083d30c3c046a3ff
#   Building wheel for wikipedia-api (setup.py) ... done
#   Created wheel for wikipedia-api: filename=Wikipedia_API-0.8.1-py3-none-any.whl size=15384 sha256=11fbe06eb2b38fa61fc595caa9651a779f87e29623600140b3dfda0e5e38a5f4
#   Stored in directory: /root/.cache/pip/wheels/0b/0f/39/e8214ec038ccd5aeb8c82b957289f2f3ab2251febeae5c2860
#   Building wheel for intervaltree (setup.py) ... done
#   Created wheel for intervaltree: filename=intervaltree-3.1.0-py2.py3-none-any.whl size=26097 sha256=a87e80cfcafd2bb401c7afa6e609e4ef4de74ef7ec7d1f1409aaa37893ebe6f5
#   Stored in directory: /root/.cache/pip/wheels/31/d7/d9/eec6891f78cac19a693bd40ecb8365d2f4613318c145ec9816
# Successfully built pinyin word2number docopt langdetect pptree sqlitedict wikipedia-api intervaltree
# Installing collected packages: word2number, sqlitedict, sortedcontainers, pptree, pinyin, docopt, xxhash, terminaltables, segtok, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, num2words, lru-dict, lemminflect, langdetect, jsonlines, jmespath, intervaltree, ftfy, dill, conllu, anytree, wikipedia-api, OpenHowNet, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, language-tool-python, botocore, bioc, s3transfer, nvidia-cusolver-cu12, mpld3, datasets, boto3, pytorch-revgrad, bert-score, transformer-smaller-training-vocab, flair, textattack
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed OpenHowNet-2.0 anytree-2.12.1 bert-score-0.3.13 bioc-2.1 boto3-1.36.26 botocore-1.36.26 conllu-4.5.3 datasets-3.3.2 dill-0.3.8 docopt-0.6.2 flair-0.15.1 ftfy-6.3.1 intervaltree-3.1.0 jmespath-1.0.1 jsonlines-4.0.0 langdetect-1.0.9 language-tool-python-2.9.0 lemminflect-0.2.3 lru-dict-1.3.0 mpld3-0.5.10 multiprocess-0.70.16 num2words-0.5.14 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pinyin-0.4.0 pptree-3.1 pytorch-revgrad-0.2.0 s3transfer-0.11.2 segtok-1.5.11 sortedcontainers-2.4.0 sqlitedict-2.1.0 terminaltables-3.1.10 textattack-0.3.10 transformer-smaller-training-vocab-0.4.0 wikipedia-api-0.8.1 word2number-1.1 xxhash-3.5.0

# %%
pip install transformers textattack torch arabert
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: textattack in /usr/local/lib/python3.11/dist-packages (0.3.10)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Collecting arabert
#   Downloading arabert-1.0.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: bert-score>=0.3.5 in /usr/local/lib/python3.11/dist-packages (from textattack) (0.3.13)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.11/dist-packages (from textattack) (0.8.1)
# Requirement already satisfied: flair in /usr/local/lib/python3.11/dist-packages (from textattack) (0.15.1)
# Requirement already satisfied: language-tool-python in /usr/local/lib/python3.11/dist-packages (from textattack) (2.9.0)
# Requirement already satisfied: lemminflect in /usr/local/lib/python3.11/dist-packages (from textattack) (0.2.3)
# Requirement already satisfied: lru-dict in /usr/local/lib/python3.11/dist-packages (from textattack) (1.3.0)
# Requirement already satisfied: datasets>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from textattack) (3.3.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from textattack) (3.9.1)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from textattack) (2.2.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from textattack) (1.13.1)
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.11/dist-packages (from textattack) (3.1.10)
# Requirement already satisfied: word2number in /usr/local/lib/python3.11/dist-packages (from textattack) (1.1)
# Requirement already satisfied: num2words in /usr/local/lib/python3.11/dist-packages (from textattack) (0.5.14)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from textattack) (10.6.0)
# Requirement already satisfied: pinyin>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from textattack) (0.4.0)
# Requirement already satisfied: jieba in /usr/local/lib/python3.11/dist-packages (from textattack) (0.42.1)
# Requirement already satisfied: OpenHowNet in /usr/local/lib/python3.11/dist-packages (from textattack) (2.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Collecting PyArabic (from arabert)
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Collecting farasapy (from arabert)
#   Downloading farasapy-0.0.14-py3-none-any.whl.metadata (8.9 kB)
# Collecting emoji==1.4.2 (from arabert)
#   Downloading emoji-1.4.2.tar.gz (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.0/185.0 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from bert-score>=0.3.5->textattack) (3.10.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.4.0->textattack) (3.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->textattack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->textattack) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.1->textattack) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: boto3>=1.20.27 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (1.36.26)
# Requirement already satisfied: conllu<5.0.0,>=4.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (4.5.3)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (1.2.18)
# Requirement already satisfied: ftfy>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (6.3.1)
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (5.2.0)
# Requirement already satisfied: langdetect>=1.0.9 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (1.0.9)
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (5.3.1)
# Requirement already satisfied: mpld3>=0.3 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (0.5.10)
# Requirement already satisfied: pptree>=3.1 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (3.1)
# Requirement already satisfied: pytorch-revgrad>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (0.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (1.6.1)
# Requirement already satisfied: segtok>=1.5.11 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (1.5.11)
# Requirement already satisfied: sqlitedict>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (2.1.0)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (0.9.0)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (0.4.0)
# Requirement already satisfied: wikipedia-api>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (0.8.1)
# Requirement already satisfied: bioc<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from flair->textattack) (2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from language-tool-python->textattack) (5.9.5)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from language-tool-python->textattack) (0.10.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->textattack) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->textattack) (1.4.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from num2words->textattack) (0.6.2)
# Requirement already satisfied: anytree in /usr/local/lib/python3.11/dist-packages (from OpenHowNet->textattack) (2.12.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from OpenHowNet->textattack) (75.1.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from PyArabic->arabert) (1.17.0)
# Requirement already satisfied: jsonlines>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from bioc<3.0.0,>=2.0.0->flair->textattack) (4.0.0)
# Requirement already satisfied: intervaltree in /usr/local/lib/python3.11/dist-packages (from bioc<3.0.0,>=2.0.0->flair->textattack) (3.1.0)
# Requirement already satisfied: botocore<1.37.0,>=1.36.26 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.20.27->flair->textattack) (1.36.26)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.20.27->flair->textattack) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.20.27->flair->textattack) (0.11.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.13->flair->textattack) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.4.0->textattack) (1.18.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy>=6.1.0->flair->textattack) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown>=4.4.0->flair->textattack) (4.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->bert-score>=0.3.5->textattack) (3.2.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.2->flair->textattack) (3.5.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair->textattack) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.25.0->flair->textattack) (4.25.6)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece,torch]<5.0,>=4.1->transformer-smaller-training-vocab>=0.2.3->flair->textattack) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown>=4.4.0->flair->textattack) (2.6)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from intervaltree->bioc<3.0.0,>=2.0.0->flair->textattack) (2.4.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown>=4.4.0->flair->textattack) (1.7.1)
# Downloading arabert-1.0.1-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.2 MB/s eta 0:00:00
# Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 10.7 MB/s eta 0:00:00
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.4.2-py3-none-any.whl size=186455 sha256=883633c69df41e77b0259dbf2238e7b080cab5bc2f38e6fa2a60efe1936b66ea
#   Stored in directory: /root/.cache/pip/wheels/94/08/b4/78657b1541bb704b088317b52429ee4016d9888fe47dbb130f
# Successfully built emoji
# Installing collected packages: emoji, PyArabic, farasapy, arabert
# Successfully installed PyArabic-0.6.15 arabert-1.0.1 emoji-1.4.2 farasapy-0.0.14

# %%
pip install transformers datasets torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.48.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.5.1+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.28.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.12)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %% [markdown]
# # MARBERT / TextFoolerJin2019.build/ arabic_preprocessed_data-3

# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.utils.data import Dataset, DataLoader
import textattack
from textattack.attack_recipes import TextFoolerJin2019
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.attack_results import SuccessfulAttackResult

# Load dataset
file_path = "/content/arabic_preprocessed_data-3.csv"
df = pd.read_csv(file_path)

# Define dataset class
class ArabicDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            padding='max_length',
            truncation=True,
            max_length=self.max_len,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'labels': torch.tensor(self.labels[idx], dtype=torch.long)
        }

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("UBC-NLP/MARBERTv2")
model = AutoModelForSequenceClassification.from_pretrained("UBC-NLP/MARBERTv2", num_labels=2)




# Wrap model for TextAttack
model_wrapper = HuggingFaceModelWrapper(model, tokenizer)

# Define attack
attack = TextFoolerJin2019.build(model_wrapper)

# Select a subset of data for attack
test_texts, test_labels = df['Text'].tolist(), df['Label'].tolist()
test_samples = list(zip(test_texts, test_labels))[:20]  # Attack first 5 samples

# Run attack
for text, label in test_samples:
    result = attack.attack(text, label)
    if isinstance(result, SuccessfulAttackResult):
        print("Original:", result.original_text)
        print("Attacked:", result.perturbed_text)
    else:
        print("Attack failed for sample:", text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/439 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.10M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/757 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/654M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at UBC-NLP/MARBERTv2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# model.safetensors:   0%|          | 0.00/654M [00:00<?, ?B/s]
# Attack failed for sample: الفيلم رائع جدا استمتعت لحظة السينما التجربة ممتعة
# Attack failed for sample: الطعام بارد جدا المطعم غير نظيف اكرر الزيارة مرة اخرى
# Attack failed for sample: احببت المكان جدا الناس ودودون الخدمة سريعة الطعام شهي جدا
# Attack failed for sample: انصح المتجر يفتقر التنوع المنتجات اسواره مرتفعة جدا
# Attack failed for sample: التجربة سيئة جدا تاخر وصول الطلب عدة ساعات الطعام غير طازج
# Attack failed for sample: الفيلم مشوق جدا الاداء التمثيلي ممتاز اعجبني شيء العمل الفني
# Attack failed for sample: الفندق رائع جدا الخدمة ممتازة الغرف صغيرة جدا
# Attack failed for sample: الطعام المكان غير طيب الاطلاق اتمكن انهاء الوجبة
# Attack failed for sample: الرحلة الجبال رائعة الطقس رائع المنظر طبيعيا جدا
# Attack failed for sample: الخدمة بطيئة جدا الطعام يفتقر النكهة اعود المطعم
# Attack failed for sample: سعيد جدا التجربة الجو هادئ المكان مريح جدا
# Attack failed for sample: الهاتف جيدا البطارية تدوم طويلا سعره مرتفعا جدا
# Attack failed for sample: الكتاب ممتازا جميع الجوانب سواء الاسلوب المحتوى
# Attack failed for sample: الجو المدينة حارا جدا كانت مناطق باردة يمكن الاستمتاع
# Attack failed for sample: السيارة ممتازة للاسف السعر مرتفعا بشكل غير معقول بالنسبة المميزات تقدمها
# Attack failed for sample: الطائرة متأخرة وصلت الخدمة متن الطائرة سيئة جدا
# Attack failed for sample: الحفلة رائعة جدا الموسيقى مميزة الاجواء مليئة الحيوية
# Attack failed for sample: الفيلم طويلا جدا الحوار بطيئا استمتعت تفاصيله
# Attack failed for sample: الموقع رائع هادئ يمكن المرء الاسترخاء بشكل تام
# Attack failed for sample: الغرف الفندق غير نظيفة تماما الخدمة سيئة جدا

# %% [markdown]
# # MARBERT/ PWWSRen2019 / arabic_preprocessed_data-3

# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.utils.data import Dataset, DataLoader
import textattack
from textattack.attack_recipes import PWWSRen2019
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.attack_results import SuccessfulAttackResult

# Load dataset
file_path = "/content/arabic_preprocessed_data-3.csv"
df = pd.read_csv(file_path)

# Define dataset class
class ArabicDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            padding='max_length',
            truncation=True,
            max_length=self.max_len,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'labels': torch.tensor(self.labels[idx], dtype=torch.long)
        }

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("UBC-NLP/MARBERTv2")
model = AutoModelForSequenceClassification.from_pretrained("UBC-NLP/MARBERTv2", num_labels=2)

# Wrap model for TextAttack
wrapped_model = HuggingFaceModelWrapper(model, tokenizer)

# Define attack
attack = PWWSRen2019.build(wrapped_model)


# Select a subset of data for attack
test_texts, test_labels = df['Text'].tolist(), df['Label'].tolist()
test_samples = list(zip(test_texts, test_labels))[:20]  # Attack first 5 samples

# Run attack
for text, label in test_samples:
    result = attack.attack(text, label)
    if isinstance(result, SuccessfulAttackResult):
        print("Original:", result.original_text)
        print("Attacked:", result.perturbed_text)
    else:
        print("Attack failed for sample:", text)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at UBC-NLP/MARBERTv2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack failed for sample: الفيلم رائع جدا استمتعت لحظة السينما التجربة ممتعة
# Attack failed for sample: الطعام بارد جدا المطعم غير نظيف اكرر الزيارة مرة اخرى
# Attack failed for sample: احببت المكان جدا الناس ودودون الخدمة سريعة الطعام شهي جدا
# Attack failed for sample: انصح المتجر يفتقر التنوع المنتجات اسواره مرتفعة جدا
# Attack failed for sample: التجربة سيئة جدا تاخر وصول الطلب عدة ساعات الطعام غير طازج
# Attack failed for sample: الفيلم مشوق جدا الاداء التمثيلي ممتاز اعجبني شيء العمل الفني
# Attack failed for sample: الفندق رائع جدا الخدمة ممتازة الغرف صغيرة جدا
# Attack failed for sample: الطعام المكان غير طيب الاطلاق اتمكن انهاء الوجبة
# Attack failed for sample: الرحلة الجبال رائعة الطقس رائع المنظر طبيعيا جدا
# Attack failed for sample: الخدمة بطيئة جدا الطعام يفتقر النكهة اعود المطعم
# Attack failed for sample: سعيد جدا التجربة الجو هادئ المكان مريح جدا
# Attack failed for sample: الهاتف جيدا البطارية تدوم طويلا سعره مرتفعا جدا
# Attack failed for sample: الكتاب ممتازا جميع الجوانب سواء الاسلوب المحتوى
# Attack failed for sample: الجو المدينة حارا جدا كانت مناطق باردة يمكن الاستمتاع
# Attack failed for sample: السيارة ممتازة للاسف السعر مرتفعا بشكل غير معقول بالنسبة المميزات تقدمها
# Attack failed for sample: الطائرة متأخرة وصلت الخدمة متن الطائرة سيئة جدا
# Attack failed for sample: الحفلة رائعة جدا الموسيقى مميزة الاجواء مليئة الحيوية
# Attack failed for sample: الفيلم طويلا جدا الحوار بطيئا استمتعت تفاصيله
# Attack failed for sample: الموقع رائع هادئ يمكن المرء الاسترخاء بشكل تام
# Attack failed for sample: الغرف الفندق غير نظيفة تماما الخدمة سيئة جدا

# %% [markdown]
# # MARBERT/ TextBuggerLi2018 / arabic_preprocessed_data-3

# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.utils.data import Dataset, DataLoader
import textattack
from textattack.attack_recipes import TextBuggerLi2018
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.attack_results import SuccessfulAttackResult

# Load dataset
file_path = "/content/arabic_preprocessed_data-3.csv"
df = pd.read_csv(file_path)

# Define dataset class
class ArabicDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            padding='max_length',
            truncation=True,
            max_length=self.max_len,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'labels': torch.tensor(self.labels[idx], dtype=torch.long)
        }

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("UBC-NLP/MARBERTv2")
model = AutoModelForSequenceClassification.from_pretrained("UBC-NLP/MARBERTv2", num_labels=2)

# Wrap model for TextAttack
model_wrapper = HuggingFaceModelWrapper(model, tokenizer)

# Define attack
attack = TextBuggerLi2018.build(model_wrapper)

# Select a subset of data for attack
test_texts, test_labels = df['Text'].tolist(), df['Label'].tolist()
test_samples = list(zip(test_texts, test_labels))[:20]  # Attack first 5 samples

# Run attack
for text, label in test_samples:
    result = attack.attack(text, label)
    if isinstance(result, SuccessfulAttackResult):
        print(f"Original: {result.original_result.attacked_text}")
        print(f"Attacked: {result.perturbed_result.attacked_text}")
    else:
        print(f"Attack failed for sample: {text}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at UBC-NLP/MARBERTv2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack failed for sample: الفيلم رائع جدا استمتعت لحظة السينما التجربة ممتعة
# Attack failed for sample: الطعام بارد جدا المطعم غير نظيف اكرر الزيارة مرة اخرى
# Original: <AttackedText "احببت المكان جدا الناس ودودون الخدمة سريعة الطعام شهي جدا">
# Attacked: <AttackedText "احببت المكان جدا الناس ودودون الخدمة سريعة الطعام شهي جا">
# Attack failed for sample: انصح المتجر يفتقر التنوع المنتجات اسواره مرتفعة جدا
# Original: <AttackedText "التجربة سيئة جدا تاخر وصول الطلب عدة ساعات الطعام غير طازج">
# Attacked: <AttackedText "التجربة س يئة جدا تاخر وصول الطلب عدة ساعات الطعام غير طازج">
# Attack failed for sample: الفيلم مشوق جدا الاداء التمثيلي ممتاز اعجبني شيء العمل الفني
# Original: <AttackedText "الفندق رائع جدا الخدمة ممتازة الغرف صغيرة جدا">
# Attacked: <AttackedText "الفندق رائع جدا الخد مة ممتازة الغرف صغيرة جدا">
# Original: <AttackedText "الطعام المكان غير طيب الاطلاق اتمكن انهاء الوجبة">
# Attacked: <AttackedText "الطعام المكان غر طيب الاطلاق اتمكن انهاء الوجبة">
# Attack failed for sample: الرحلة الجبال رائعة الطقس رائع المنظر طبيعيا جدا
# Original: <AttackedText "الخدمة بطيئة جدا الطعام يفتقر النكهة اعود المطعم">
# Attacked: <AttackedText "الخدمة بطيئة جدا الطعام يفتقر ال نكهة اعود المطعم">
# Attack failed for sample: سعيد جدا التجربة الجو هادئ المكان مريح جدا
# Original: <AttackedText "الهاتف جيدا البطارية تدوم طويلا سعره مرتفعا جدا">
# Attacked: <AttackedText "الهاتف جدا البطارية تدوم طويلا سعره مرتفعا جدا">
# Attack failed for sample: الكتاب ممتازا جميع الجوانب سواء الاسلوب المحتوى
# Attack failed for sample: الجو المدينة حارا جدا كانت مناطق باردة يمكن الاستمتاع
# Original: <AttackedText "السيارة ممتازة للاسف السعر مرتفعا بشكل غير معقول بالنسبة المميزات تقدمها">
# Attacked: <AttackedText "السيارة م متازة للسف السعر مرتفعا بشكل غير معقول بالنسبة المميزات تقدمها">
# Original: <AttackedText "الطائرة متأخرة وصلت الخدمة متن الطائرة سيئة جدا">
# Attacked: <AttackedText "ال طائرة متأخرة وصلت الخدمة متن الطائرة سيئة جدا">
# Attack failed for sample: الحفلة رائعة جدا الموسيقى مميزة الاجواء مليئة الحيوية
# Attack failed for sample: الفيلم طويلا جدا الحوار بطيئا استمتعت تفاصيله
# Original: <AttackedText "الموقع رائع هادئ يمكن المرء الاسترخاء بشكل تام">
# Attacked: <AttackedText "الموقع رائع هادئ يمكن المرء الاتسرخاء بشكل تام">
# Attack failed for sample: الغرف الفندق غير نظيفة تماما الخدمة سيئة جدا

# %% [markdown]
# # MARBERT/ GeneticAlgorithmAlzantot2018 / arabic_preprocessed_data-3

# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.utils.data import Dataset, DataLoader
import textattack
from textattack.attack_recipes import GeneticAlgorithmAlzantot2018
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.attack_results import SuccessfulAttackResult

# Load dataset
file_path = "/content/arabic_preprocessed_data-3.csv"
df = pd.read_csv(file_path)

# Define dataset class
class ArabicDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            padding='max_length',
            truncation=True,
            max_length=self.max_len,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'labels': torch.tensor(self.labels[idx], dtype=torch.long)
        }

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("UBC-NLP/MARBERTv2")
model = AutoModelForSequenceClassification.from_pretrained("UBC-NLP/MARBERTv2", num_labels=2)

# Wrap model for TextAttack
model_wrapper = HuggingFaceModelWrapper(model, tokenizer)

# Define attack
attack = GeneticAlgorithmAlzantot2018.build(model_wrapper)

# Select a subset of data for attack
test_texts, test_labels = df['Text'].tolist(), df['Label'].tolist()
test_samples = list(zip(test_texts, test_labels))[:20]  # Attack first 5 samples

# Run attack
for text, label in test_samples:
    result = attack.attack(text, label)
    if isinstance(result, SuccessfulAttackResult):
        print(f"Original: {result.original_result.attacked_text}")
        print(f"Attacked: {result.perturbed_result.attacked_text}")
    else:
        print(f"Attack failed for sample: {text}")
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at UBC-NLP/MARBERTv2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# textattack: Downloading https://textattack.s3.amazonaws.com/constraints/semantics/language-models/alzantot-goog-lm.
# 100%|██████████| 3.87G/3.87G [02:11<00:00, 29.4MB/s]
# textattack: Unzipping file /root/.cache/textattack/tmp1nc0frdj.zip to /root/.cache/textattack/constraints/semantics/language-models/alzantot-goog-lm.
# textattack: Successfully saved constraints/semantics/language-models/alzantot-goog-lm to cache.
# Recovering graph.
# INFO:tensorflow:Recovering Graph /root/.cache/textattack/constraints/semantics/language-models/alzantot-goog-lm/graph-2016-09-10-gpu.pbtxt
# Recovering checkpoint /root/.cache/textattack/constraints/semantics/language-models/alzantot-goog-lm/ckpt-*
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack failed for sample: الفيلم رائع جدا استمتعت لحظة السينما التجربة ممتعة
# Attack failed for sample: الطعام بارد جدا المطعم غير نظيف اكرر الزيارة مرة اخرى
# Attack failed for sample: احببت المكان جدا الناس ودودون الخدمة سريعة الطعام شهي جدا
# Attack failed for sample: انصح المتجر يفتقر التنوع المنتجات اسواره مرتفعة جدا
# Attack failed for sample: التجربة سيئة جدا تاخر وصول الطلب عدة ساعات الطعام غير طازج
# Attack failed for sample: الفيلم مشوق جدا الاداء التمثيلي ممتاز اعجبني شيء العمل الفني
# Attack failed for sample: الفندق رائع جدا الخدمة ممتازة الغرف صغيرة جدا
# Attack failed for sample: الطعام المكان غير طيب الاطلاق اتمكن انهاء الوجبة
# Attack failed for sample: الرحلة الجبال رائعة الطقس رائع المنظر طبيعيا جدا
# Attack failed for sample: الخدمة بطيئة جدا الطعام يفتقر النكهة اعود المطعم
# Attack failed for sample: سعيد جدا التجربة الجو هادئ المكان مريح جدا
# Attack failed for sample: الهاتف جيدا البطارية تدوم طويلا سعره مرتفعا جدا
# Attack failed for sample: الكتاب ممتازا جميع الجوانب سواء الاسلوب المحتوى
# Attack failed for sample: الجو المدينة حارا جدا كانت مناطق باردة يمكن الاستمتاع
# Attack failed for sample: السيارة ممتازة للاسف السعر مرتفعا بشكل غير معقول بالنسبة المميزات تقدمها
# Attack failed for sample: الطائرة متأخرة وصلت الخدمة متن الطائرة سيئة جدا
# Attack failed for sample: الحفلة رائعة جدا الموسيقى مميزة الاجواء مليئة الحيوية
# Attack failed for sample: الفيلم طويلا جدا الحوار بطيئا استمتعت تفاصيله
# Attack failed for sample: الموقع رائع هادئ يمكن المرء الاسترخاء بشكل تام
# Attack failed for sample: الغرف الفندق غير نظيفة تماما الخدمة سيئة جدا

# %% [markdown]
# # MARBERT -BERT-Attack- arabic_preprocessed_data-3

# %%
import torch
import pandas as pd
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from torch.utils.data import Dataset, DataLoader
import textattack
from textattack.attack_recipes import BERTAttackLi2020
from textattack.models.wrappers import HuggingFaceModelWrapper
from textattack.attack_results import SuccessfulAttackResult

# Load dataset
file_path = "/content/arabic_preprocessed_data-3.csv"
df = pd.read_csv(file_path)

# Define dataset class
class ArabicDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        encoding = self.tokenizer(
            self.texts[idx],
            padding='max_length',
            truncation=True,
            max_length=self.max_len,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'labels': torch.tensor(self.labels[idx], dtype=torch.long)
        }

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained("UBC-NLP/MARBERTv2")
model = AutoModelForSequenceClassification.from_pretrained("UBC-NLP/MARBERTv2", num_labels=2)

# Wrap model for TextAttack
model_wrapper = HuggingFaceModelWrapper(model, tokenizer)

# Define attack
attack = BERTAttackLi2020.build(model_wrapper)

# Select a subset of data for attack
test_texts, test_labels = df['Text'].tolist(), df['Label'].tolist()
test_samples = list(zip(test_texts, test_labels))[:20]  # Attack first 5 samples

# Run attack
for text, label in test_samples:
    result = attack.attack(text, label)
    if isinstance(result, SuccessfulAttackResult):
        print(f"Original: {result.original_result.attacked_text}")
        print(f"Attacked: {result.perturbed_result.attacked_text}")
    else:
        print(f"Attack failed for sample: {text}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at UBC-NLP/MARBERTv2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForMaskedLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack failed for sample: الفيلم رائع جدا استمتعت لحظة السينما التجربة ممتعة
# Attack failed for sample: الطعام بارد جدا المطعم غير نظيف اكرر الزيارة مرة اخرى
# Attack failed for sample: احببت المكان جدا الناس ودودون الخدمة سريعة الطعام شهي جدا
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# DEBUG:jieba:Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.969 seconds.
# DEBUG:jieba:Loading model cost 0.969 seconds.
# Prefix dict has been built successfully.
# DEBUG:jieba:Prefix dict has been built successfully.

# %%
# !textattack attack --model-from-huggingface UBC-NLP/MARBERTv2 --dataset-from-file arabic_preprocessed_data-3.py --recipe deepwordbug --num-examples 20
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 2025-02-24 08:44:24.585682: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740386664.795070    2045 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740386664.859249    2045 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-24 08:44:25.314820: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# textattack: Loading model and tokenizer from file: None
# textattack: Loading module from `arabic_preprocessed_data-3.py`.
# textattack: Loading pre-trained model from HuggingFace model repository: UBC-NLP/MARBERTv2
# config.json: 100% 757/757 [00:00<00:00, 4.47MB/s]
# pytorch_model.bin: 100% 654M/654M [00:18<00:00, 36.0MB/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at UBC-NLP/MARBERTv2 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json: 100% 439/439 [00:00<00:00, 2.61MB/s]
# vocab.txt:   0% 0.00/1.10M [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/654M [00:00<?, ?B/s]
# vocab.txt: 100% 1.10M/1.10M [00:00<00:00, 1.57MB/s]
#
# model.safetensors:   3% 21.0M/654M [00:00<00:18, 34.8MB/s]
# model.safetensors:   5% 31.5M/654M [00:00<00:17, 35.7MB/s]
# model.safetensors:   6% 41.9M/654M [00:01<00:17, 35.4MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 539kB/s]
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  unk
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  CompositeTransformation(
#     (0): WordSwapNeighboringCharacterSwap(
#         (random_one):  True
#       )
#     (1): WordSwapRandomCharacterSubstitution(
#         (random_one):  True
#       )
#     (2): WordSwapRandomCharacterDeletion(
#         (random_one):  True
#       )
#     (3): WordSwapRandomCharacterInsertion(
#         (random_one):  True
#       )
#     )
#   (constraints):
#     (0): LevenshteinEditDistance(
#         (max_edit_distance):  30
#         (compare_against_original):  True
#       )
#     (1): RepeatModification
#     (2): StopwordModification
#   (is_black_box):  True
# )
#
#
#   0% 0/20 [00:00<?, ?it/s]
# model.safetensors:  13% 83.9M/654M [00:02<00:15, 37.8MB/s]
# model.safetensors:  14% 94.4M/654M [00:02<00:15, 37.3MB/s]
# model.safetensors:  16% 105M/654M [00:02<00:14, 36.7MB/s]
# model.safetensors:  18% 115M/654M [00:03<00:14, 36.5MB/s]
# model.safetensors:  19% 126M/654M [00:03<00:14, 36.3MB/s]
#   5% 1/20 [00:02<00:38,  2.02s/it]--------------------------------------------- Result 1 ---------------------------------------------
# 0 (50%) --> [38:5:240m[SKIPPED]
#
# الفيلم رائع جدا استمتعت لحظة السينما التجربة ممتعة
#
#
# [Succeeded / Failed / Skipped / Total] 0 / 0 / 1 / 1:   5% 1/20 [00:02<00:38,  2.02s/it]
# model.safetensors:  22% 147M/654M [00:04<00:14, 35.9MB/s]
# model.safetensors:  24% 157M/654M [00:04<00:13, 36.0MB/s]
# model.safetensors:  26% 168M/654M [00:04<00:13, 35.7MB/s]
# model.safetensors:  27% 178M/654M [00:05<00:13, 35.9MB/s]
# model.safetensors:  29% 189M/654M [00:05<00:12, 35.8MB/s]
# model.safetensors:  30% 199M/654M [00:05<00:12, 35.8MB/s]
# model.safetensors:  32% 210M/654M [00:05<00:12, 35.2MB/s]
# model.safetensors:  34% 220M/654M [00:06<00:12, 34.6MB/s]
# model.safetensors:  35% 231M/654M [00:06<00:12, 34.8MB/s]
# model.safetensors:  37% 241M/654M [00:06<00:11, 35.1MB/s]
# model.safetensors:  38% 252M/654M [00:07<00:11, 35.2MB/s]
# model.safetensors:  40% 262M/654M [00:07<00:11, 32.9MB/s]
# model.safetensors:  42% 273M/654M [00:07<00:11, 33.5MB/s]
# model.safetensors:  43% 283M/654M [00:08<00:10, 34.2MB/s]
# model.safetensors:  45% 294M/654M [00:08<00:10, 34.6MB/s]
# model.safetensors:  46% 304M/654M [00:08<00:10, 34.9MB/s]
# model.safetensors:  48% 315M/654M [00:08<00:09, 35.2MB/s]
# model.safetensors:  50% 325M/654M [00:09<00:09, 35.3MB/s]
# model.safetensors:  51% 336M/654M [00:09<00:09, 35.1MB/s]
# model.safetensors:  53% 346M/654M [00:09<00:08, 35.2MB/s]
# model.safetensors:  54% 357M/654M [00:10<00:08, 35.6MB/s]
# model.safetensors:  56% 367M/654M [00:10<00:08, 35.1MB/s]
# model.safetensors:  58% 377M/654M [00:10<00:07, 36.0MB/s]
# model.safetensors:  59% 388M/654M [00:11<00:07, 35.9MB/s]
# model.safetensors:  61% 398M/654M [00:11<00:07, 35.8MB/s]
# model.safetensors:  63% 409M/654M [00:11<00:06, 35.7MB/s]
# model.safetensors:  64% 419M/654M [00:11<00:06, 35.6MB/s]
# model.safetensors:  66% 430M/654M [00:12<00:06, 35.7MB/s]
# model.safetensors:  67% 440M/654M [00:12<00:06, 35.6MB/s]
# model.safetensors:  69% 451M/654M [00:12<00:05, 35.7MB/s]
# model.safetensors:  71% 461M/654M [00:13<00:05, 35.6MB/s]
# model.safetensors:  72% 472M/654M [00:13<00:05, 35.4MB/s]
# model.safetensors:  74% 482M/654M [00:13<00:04, 35.7MB/s]
# model.safetensors:  75% 493M/654M [00:13<00:04, 35.7MB/s]
# model.safetensors:  77% 503M/654M [00:14<00:04, 35.7MB/s]
# model.safetensors:  79% 514M/654M [00:14<00:03, 35.7MB/s]
# model.safetensors:  80% 524M/654M [00:14<00:03, 35.4MB/s]
# model.safetensors:  82% 535M/654M [00:15<00:03, 35.6MB/s]
# model.safetensors:  83% 545M/654M [00:15<00:03, 35.7MB/s]
# model.safetensors:  85% 556M/654M [00:15<00:02, 35.7MB/s]
# model.safetensors:  87% 566M/654M [00:16<00:02, 35.7MB/s]
# model.safetensors:  88% 577M/654M [00:16<00:02, 35.6MB/s]
# model.safetensors:  90% 587M/654M [00:16<00:01, 34.8MB/s]
# model.safetensors:  91% 598M/654M [00:16<00:01, 35.1MB/s]
# model.safetensors:  93% 608M/654M [00:17<00:01, 35.1MB/s]
# model.safetensors:  95% 619M/654M [00:17<00:01, 35.2MB/s]
# model.safetensors:  96% 629M/654M [00:17<00:00, 35.1MB/s]
# model.safetensors:  98% 640M/654M [00:18<00:00, 35.2MB/s]
# model.safetensors: 100% 654M/654M [00:18<00:00, 35.3MB/s]
# [Succeeded / Failed / Skipped / Total] 0 / 0 / 1 / 1:  10% 2/20 [00:29<04:22, 14.60s/it]--------------------------------------------- Result 2 ---------------------------------------------
# 0 (50%) --> 1 (51%)
#
# الطعام بارد جدا المطعم غير نظيف اكرر الزيارة مرة اخرى
#
# الطعام بارد جدا المطعم غير نظيف اكرر الزيارEة مرة اخرى
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 0 / 1 / 2:  15% 3/20 [00:31<03:01, 10.66s/it]--------------------------------------------- Result 3 ---------------------------------------------
# 0 (50%) --> [38:5:240m[SKIPPED]
#
# احببت المكان جدا الناس ودودون الخدمة سريعة الطعام شهي جدا
#
#
# [Succeeded / Failed / Skipped / Total] 1 / 0 / 2 / 3:  20% 4/20 [01:32<06:09, 23.08s/it]--------------------------------------------- Result 4 ---------------------------------------------
# 0 (52%) --> 1 (50%)
#
# انصح المتجر يفتقر التنوع المنتجات اسواره مرتفعة جدا
#
# انصح المتجر يفتقر التنوع امنتجات اسوراه مرتفعة دا
#
#
# [Succeeded / Failed / Skipped / Total] 2 / 0 / 2 / 4:  25% 5/20 [01:59<05:59, 23.97s/it]--------------------------------------------- Result 5 ---------------------------------------------
# 0 (52%) --> 1 (51%)
#
# التجربة سيئة جدا تاخر وصول الطلب عدة ساعات الطعام غير طازج
#
# التجربة سيئd جدا تاخر وصول الطلب عدة ساعات الطعام غير طازج
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 2 / 5:  30% 6/20 [02:01<04:43, 20.27s/it]--------------------------------------------- Result 6 ---------------------------------------------
# 0 (53%) --> [38:5:240m[SKIPPED]
#
# الفيلم مشوق جدا الاداء التمثيلي ممتاز اعجبني شيء العمل الفني
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 3 / 6:  35% 7/20 [02:03<03:48, 17.58s/it]--------------------------------------------- Result 7 ---------------------------------------------
# 0 (51%) --> [38:5:240m[SKIPPED]
#
# الفندق رائع جدا الخدمة ممتازة الغرف صغيرة جدا
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 4 / 7:  40% 8/20 [02:04<03:06, 15.57s/it]--------------------------------------------- Result 8 ---------------------------------------------
# 1 (51%) --> [38:5:240m[SKIPPED]
#
# الطعام المكان غير طيب الاطلاق اتمكن انهاء الوجبة
#
#
# [Succeeded / Failed / Skipped / Total] 3 / 0 / 5 / 8:  45% 9/20 [02:26<02:58, 16.24s/it]--------------------------------------------- Result 9 ---------------------------------------------
# 1 (50%) --> 0 (52%)
#
# الرحلة الجبال رائعة الطقس رائع المنظر طبيعيا جدا
#
# الرحlة الجبال رائعة الطقس رائع المنظر طبيعيا جدا
#
#
# [Succeeded / Failed / Skipped / Total] 4 / 0 / 5 / 9:  50% 10/20 [02:46<02:46, 16.68s/it]--------------------------------------------- Result 10 ---------------------------------------------
# 0 (51%) --> 1 (50%)
#
# الخدمة بطيئة جدا الطعام يفتقر النكهة اعود المطعم
#
# الخدة بطيئة جدا الطعام يفتقر النكهة اعود المطعم
#
#
# [Succeeded / Failed / Skipped / Total] 5 / 0 / 5 / 10:  55% 11/20 [03:08<02:34, 17.13s/it]--------------------------------------------- Result 11 ---------------------------------------------
# 1 (54%) --> 0 (52%)
#
# سعيد جدا التجربة الجو هادئ المكان مريح جدا
#
# سعيد جدا الجتربة الجو هادئ المكان مريح جدا
#
#
# [Succeeded / Failed / Skipped / Total] 6 / 0 / 5 / 11:  60% 12/20 [03:42<02:28, 18.55s/it]--------------------------------------------- Result 12 ---------------------------------------------
# 0 (51%) --> 1 (50%)
#
# الهاتف جيدا البطارية تدوم طويلا سعره مرتفعا جدا
#
# الهاتH جيدا البطرية تدوم طويلا سعره مرتفعا جدا
#
#
# [Succeeded / Failed / Skipped / Total] 7 / 0 / 5 / 12:  65% 13/20 [04:01<02:10, 18.58s/it]--------------------------------------------- Result 13 ---------------------------------------------
# 1 (50%) --> 0 (52%)
#
# الكتاب ممتازا جميع الجوانب سواء الاسلوب المحتوى
#
# الكتاب ممتازا جميع الجوانب واء الاسلوب المحتوى
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 0 / 5 / 13:  70% 14/20 [04:03<01:44, 17.36s/it]--------------------------------------------- Result 14 ---------------------------------------------
# 0 (52%) --> [38:5:240m[SKIPPED]
#
# الجو المدينة حارا جدا كانت مناطق باردة يمكن الاستمتاع
#
#
# [Succeeded / Failed / Skipped / Total] 8 / 0 / 6 / 14:  75% 15/20 [04:36<01:32, 18.40s/it]--------------------------------------------- Result 15 ---------------------------------------------
# 0 (51%) --> 1 (52%)
#
# السيارة ممتازة للاسف السعر مرتفعا بشكل غير معقول بالنسبة المميزات تقدمها
#
# السيارة ممتازة للاس السعر مرتفعا بشكل غير معقول بالنسبة المميزات تقدمها
#
#
# [Succeeded / Failed / Skipped / Total] 9 / 0 / 6 / 15:  80% 16/20 [05:03<01:15, 18.97s/it]--------------------------------------------- Result 16 ---------------------------------------------
# 0 (52%) --> 1 (50%)
#
# الطائرة متأخرة وصلت الخدمة متن الطائرة سيئة جدا
#
# الطائرة متأخرة وصلت الخدمة من الطائرة سيئة جدا
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 0 / 6 / 16:  85% 17/20 [05:05<00:53, 17.94s/it]--------------------------------------------- Result 17 ---------------------------------------------
# 0 (51%) --> [38:5:240m[SKIPPED]
#
# الحفلة رائعة جدا الموسيقى مميزة الاجواء مليئة الحيوية
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 0 / 7 / 17:  90% 18/20 [05:06<00:34, 17.03s/it]--------------------------------------------- Result 18 ---------------------------------------------
# 1 (53%) --> [38:5:240m[SKIPPED]
#
# الفيلم طويلا جدا الحوار بطيئا استمتعت تفاصيله
#
#
# [Succeeded / Failed / Skipped / Total] 10 / 0 / 8 / 18:  95% 19/20 [05:29<00:17, 17.37s/it]--------------------------------------------- Result 19 ---------------------------------------------
# 1 (51%) --> 0 (53%)
#
# الموقع رائع هادئ يمكن المرء الاسترخاء بشكل تام
#
# الموقع رائع هادئ يمكن sالمرء الاسترخاء بشكل تام
#
#
# [Succeeded / Failed / Skipped / Total] 11 / 0 / 8 / 19: 100% 20/20 [06:22<00:00, 19.13s/it]--------------------------------------------- Result 20 ---------------------------------------------
# 0 (51%) --> 1 (50%)
#
# الغرف الفندق غير نظيفة تماما الخدمة سيئة جدا
#
# الغرف لفندق غير نظيفq تماما الخدمة سيئ جدا
#
#
# [Succeeded / Failed / Skipped / Total] 12 / 0 / 8 / 20: 100% 20/20 [06:22<00:00, 19.13s/it]
#
# +-------------------------------+--------+
# | Attack Results                |        |
# +-------------------------------+--------+
# | Number of successful attacks: | 12     |
# | Number of failed attacks:     | 0      |
# | Number of skipped attacks:    | 8      |
# | Original accuracy:            | 60.0%  |
# | Accuracy under attack:        | 0.0%   |
# | Attack success rate:          | 100.0% |
# | Average perturbed word %:     | 17.08% |
# | Average num. words per input: | 8.55   |
# | Avg num queries:              | 18.58  |
# +-------------------------------+--------+
